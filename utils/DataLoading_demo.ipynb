# %%
import os
import cv2
import numpy as np
from itertools import combinations
from tqdm import tqdm
from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import torch

from DataLoading import DataDiscovering, DataReading
from visualize import visualize

# %%
Dir = DataDiscovering('E:/TIANCHI')
train_data, val_data, test_data = Dir.reading_data(random_subset=100)
transform = transforms.Compose([transforms.ToTensor()])
train_set = DataReading(train_data,transform = transform)
# Out:
# ...
# loading train&test data: 100%|###########################################################| 2/2 [00:00<00:00, 33.89it/s]

# %%
Vis = visualize()
Vis.dataloading_visualize(train_set[7])
